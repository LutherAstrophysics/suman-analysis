# %%
from trout.stars import STAR_START, STAR_END

# %%
STAR_START
# Out:
# 1

# %%
STAR_END
# Out:
# 2510

# %%
from trout.stars import get_star

# %%
s7 = get_star(7)

# %%
s7
# Out:
# Star: 7 Datapoints: 791 Selected: 0

# %%
help(s7)
# Out:
# Help on Star in module trout.stars.star object:
#
# class Star(builtins.object)
#  |  Star(number: int, is_primary: bool = True)
#  |
#  |  A star object, useful for viewing data for the star, advanced filtering of
#  |  data and drawing scatter plot of the data.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, number: int, is_primary: bool = True)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
#  |  attendance(self, year: Optional[int] = None, print_stats=False) -> float
#  |      Calculates the attendance % of the star. The attendance is calculated
#  |      after removing the bad nights.
#  |
#  |      param: (optional) year for which to calculate attendance. Default to
#  |              all years
#  |      return: the attendance percentage in given year or the entire period
#  |
# ...

# %%
s7.get_color()

# %%
s7.select("date > '2005-01-01'")
# Out:
# Star: 7 Datapoints: 791 Selected: 191

# %%
s7.plot()

# %%
s7.select('')
# Out:
# Star: 7 Datapoints: 791 Selected: 218

# %%
s7.plot()

# %%
s7.select_year(2011)
# Out:
# Star: 7 Datapoints: 791 Selected: 14

# %%
s7.mean()
# Out:
# 462928.5714285714

# %%
s7.selected_data
# Out:
# [(446, 474000.0, datetime.date(2011, 3, 15)),
#  (451, 473000.0, datetime.date(2011, 4, 1)),
#  (452, 476000.0, datetime.date(2011, 4, 4)),
#  (454, 467000.0, datetime.date(2011, 4, 28)),
#  (456, 468000.0, datetime.date(2011, 5, 3)),
#  (460, 467000.0, datetime.date(2011, 5, 31)),
#  (462, 456000.0, datetime.date(2011, 6, 27)),
#  (463, 461000.0, datetime.date(2011, 6, 28)),
#  (465, 459000.0, datetime.date(2011, 7, 2)),
#  (467, 452000.0, datetime.date(2011, 7, 8)),
#  (469, 453000.0, datetime.date(2011, 7, 24)),
#  (472, 468000.0, datetime.date(2011, 8, 6)),
#  (484, 452000.0, datetime.date(2011, 9, 8)),
#  (487, 455000.0, datetime.date(2011, 9, 11))]

# %%
s7.select_year(2011, exclude_bad_nights=False)
# Out:
# Star: 7 Datapoints: 791 Selected: 15

# %%
s7.plot()
