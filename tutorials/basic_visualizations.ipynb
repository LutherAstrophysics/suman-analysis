# %%
from trout.vis import field, print_step_details

# %%
import warnings
warnings.simplefilter('ignore')

# %%
field()

# %%
from trout.vis import attendance_plot, attendance_plot_by_median

# %%
attendance_plot(82)

# %%
attendance_plot_by_median(82)

# %%
print_step_details(1, 10, 2011, 2012)
True
# Out:
# Stars 1-10
# Step 2011-2012
# Displaying neighbors within distance: 8
#
# Star      X         Y         Step      Color     Internight Band          ClstNeig  ClstNeigDist        Neighbors
# 1         746.58    459.64    0.86      0.36      COLOR_BAND_1             1919      16.57
# 5         112.45    420.52    0.91      0.67      COLOR_BAND_2             2413      20.38
# 4         230.97    347.20    0.92      0.74      COLOR_BAND_2             474       10.64
# 3         462.38    523.01    0.92      0.76      COLOR_BAND_2             675       13.43
# 6         153.63    614.49    0.93      0.32      COLOR_BAND_1             1165      15.13
# 2         547.57    493.95    0.95      0.66      COLOR_BAND_2             1503      11.80
# 10        369.82    409.03    0.95      0.20      COLOR_BAND_1             890       13.43
# 8         500.73    376.04    0.96      0.28      COLOR_BAND_1             1920      15.61
# ...
